# %% [markdown]
# ## Step 1: Dataset 및 Activation 함수 변경

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from matplotlib import pyplot as plt
import torch.nn as nn
import torch.optim as optim

# 1. Dataset 로딩 (CIFAR10)
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # CIFAR10 데이터 정규화
])

# Train 데이터 로딩
trainset = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

# Test 데이터 로딩
testset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
    transform=transform
)

# Train/Test 데이터 로더
batch_size = 256
trainloader = torch.utils.data.DataLoader(
    trainset,
    batch_size=batch_size,
    shuffle=True
)

testloader = torch.utils.data.DataLoader(
    testset,
    batch_size=batch_size,
    shuffle=False
)

# 데이터 형태 확인
dataiter = iter(trainloader)
images, labels = next(dataiter)
print(images.shape, labels.shape)  # CIFAR10의 입력 shape 확인

# CIFAR10은 (3, 32, 32)의 shape을 가짐
plt.imshow(trainset[0][0].permute(1, 2, 0) * 0.5 + 0.5)  # 이미지 시각화
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([256, 3, 32, 32]) torch.Size([256])

# %% [markdown]
# ## Step 2: 모델 정의 (Activation 함수 LeakyReLU로 변경)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)  # 3 채널 (RGB 이미지)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(64 * 8 * 8, 128)  # CIFAR10은 (32x32)이므로 (64 * 8 * 8)로 변경
        self.fc2 = nn.Linear(128, 10)  # Output: 10 classes (CIFAR10)

    def forward(self, x):
        x = self.pool(nn.LeakyReLU()(self.conv1(x)))  # LeakyReLU 사용
        x = self.pool(nn.LeakyReLU()(self.conv2(x)))
        x = x.view(-1, 64 * 8 * 8)  # Flatten the tensor
        x = nn.LeakyReLU()(self.fc1(x))
        x = self.fc2(x)  # No activation here, CrossEntropyLoss includes softmax
        return x

# %% [markdown]
# ## Step 3: Optimizer 설정 및 SGD와 Adam 성능 비교

# %%
import numpy as np
import torch.optim as optim
import torch.nn as nn
import torch

# 모델 가중치 초기화 함수
def initialize_weights(model):
    for layer in model.modules():
        if isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear):
            nn.init.kaiming_normal_(layer.weight)  # He 초기화
            if layer.bias is not None:
                nn.init.zeros_(layer.bias)  # bias 초기화

def accuracy(model, dataloader):
    cnt = 0
    acc = 0

    model.eval()  # 평가 모드로 설정
    with torch.no_grad():  # Gradient 계산 안 함
        for data in dataloader:
            inputs, labels = data
            inputs, labels = inputs.to('cuda'), labels.to('cuda')

            preds = model(inputs)
            preds = torch.argmax(preds, dim=-1)  # 예측값의 인덱스 (클래스)

            cnt += labels.shape[0]
            acc += (labels == preds).sum().item()

    return acc / cnt

def train_model(optimizer_name="adam"):
    # Optimizer 설정
    if optimizer_name == "adam":
        optimizer = optim.Adam(model.parameters(), lr=0.001)
    elif optimizer_name == "sgd":
        optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

    n_epochs = 50
    train_accuracies = []
    test_accuracies = []

    for epoch in range(n_epochs):
        model.train()  # 학습 모드로 설정
        running_loss = 0.0

        for data in trainloader:
            inputs, labels = data
            inputs, labels = inputs.to('cuda'), labels.to('cuda')

            # 옵티마이저 초기화
            optimizer.zero_grad()

            # Forward
            outputs = model(inputs)
            loss = loss_fn(outputs, labels)

            # Backward
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        # 매 에포크마다 train과 test 정확도 계산
        train_acc = accuracy(model, trainloader)
        test_acc = accuracy(model, testloader)

        train_accuracies.append(train_acc)
        test_accuracies.append(test_acc)

        print(f'Epoch {epoch+1}, Loss: {running_loss/len(trainloader):.4f}, '
              f'Train Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}')

    return train_accuracies, test_accuracies

# Adam과 SGD 비교
model = Net().to('cuda')
loss_fn = nn.CrossEntropyLoss()

# Adam 옵티마이저로 학습
initialize_weights(model)  # 모델 가중치 초기화
adam_train_acc, adam_test_acc = train_model("adam")

# SGD 옵티마이저로 학습
initialize_weights(model)  # 모델 가중치 다시 초기화
sgd_train_acc, sgd_test_acc = train_model("sgd")

# Plot 1: SGD와 Adam 성능 비교
def plot_acc(train_acc1, train_acc2, label1='Adam', label2='SGD'):
    x = np.arange(len(train_acc1))

    plt.plot(x, train_acc1, label=label1)
    plt.plot(x, train_acc2, label=label2)
    plt.xlabel('Epochs')
    plt.ylabel('Train Accuracy')
    plt.legend()
    plt.show()

plot_acc(adam_train_acc, sgd_train_acc)
# Out:
# Epoch 1, Loss: 1.5516, Train Accuracy: 0.5594, Test Accuracy: 0.5442
# Epoch 2, Loss: 1.0843, Train Accuracy: 0.6731, Test Accuracy: 0.6459
# Epoch 3, Loss: 0.9270, Train Accuracy: 0.7204, Test Accuracy: 0.6682
# Epoch 4, Loss: 0.8259, Train Accuracy: 0.7327, Test Accuracy: 0.6795
# Epoch 5, Loss: 0.7451, Train Accuracy: 0.7543, Test Accuracy: 0.6814
# Epoch 6, Loss: 0.6893, Train Accuracy: 0.7805, Test Accuracy: 0.6915
# Epoch 7, Loss: 0.6265, Train Accuracy: 0.8175, Test Accuracy: 0.7108
# Epoch 8, Loss: 0.5766, Train Accuracy: 0.8305, Test Accuracy: 0.7077
# Epoch 9, Loss: 0.5259, Train Accuracy: 0.8480, Test Accuracy: 0.7114
# Epoch 10, Loss: 0.4871, Train Accuracy: 0.8624, Test Accuracy: 0.7068
# Epoch 11, Loss: 0.4333, Train Accuracy: 0.8872, Test Accuracy: 0.7096
# Epoch 12, Loss: 0.3847, Train Accuracy: 0.8974, Test Accuracy: 0.7043
# Epoch 13, Loss: 0.3538, Train Accuracy: 0.8992, Test Accuracy: 0.7024
# Epoch 14, Loss: 0.3167, Train Accuracy: 0.9015, Test Accuracy: 0.6957
# Epoch 15, Loss: 0.2766, Train Accuracy: 0.9305, Test Accuracy: 0.7019
# Epoch 16, Loss: 0.2396, Train Accuracy: 0.9317, Test Accuracy: 0.7001
# Epoch 17, Loss: 0.2023, Train Accuracy: 0.9556, Test Accuracy: 0.6993
# Epoch 18, Loss: 0.1807, Train Accuracy: 0.9607, Test Accuracy: 0.6988
# Epoch 19, Loss: 0.1492, Train Accuracy: 0.9718, Test Accuracy: 0.6988
# Epoch 20, Loss: 0.1226, Train Accuracy: 0.9679, Test Accuracy: 0.6958
# Epoch 21, Loss: 0.1022, Train Accuracy: 0.9815, Test Accuracy: 0.6917
# Epoch 22, Loss: 0.0881, Train Accuracy: 0.9819, Test Accuracy: 0.6944
# Epoch 23, Loss: 0.0711, Train Accuracy: 0.9919, Test Accuracy: 0.6974
# Epoch 24, Loss: 0.0633, Train Accuracy: 0.9816, Test Accuracy: 0.6937
# Epoch 25, Loss: 0.0585, Train Accuracy: 0.9825, Test Accuracy: 0.6905
# Epoch 26, Loss: 0.0664, Train Accuracy: 0.9791, Test Accuracy: 0.6878
# Epoch 27, Loss: 0.0526, Train Accuracy: 0.9831, Test Accuracy: 0.6871
# Epoch 28, Loss: 0.0474, Train Accuracy: 0.9885, Test Accuracy: 0.6909
# Epoch 29, Loss: 0.0561, Train Accuracy: 0.9892, Test Accuracy: 0.6924
# Epoch 30, Loss: 0.0534, Train Accuracy: 0.9901, Test Accuracy: 0.6866
# Epoch 31, Loss: 0.0484, Train Accuracy: 0.9921, Test Accuracy: 0.6891
# Epoch 32, Loss: 0.0288, Train Accuracy: 0.9960, Test Accuracy: 0.6909
# Epoch 33, Loss: 0.0193, Train Accuracy: 0.9989, Test Accuracy: 0.6953
# Epoch 34, Loss: 0.0059, Train Accuracy: 1.0000, Test Accuracy: 0.6977
# Epoch 35, Loss: 0.0029, Train Accuracy: 1.0000, Test Accuracy: 0.6989
# Epoch 36, Loss: 0.0018, Train Accuracy: 1.0000, Test Accuracy: 0.6998
# Epoch 37, Loss: 0.0014, Train Accuracy: 1.0000, Test Accuracy: 0.7008
# Epoch 38, Loss: 0.0012, Train Accuracy: 1.0000, Test Accuracy: 0.7031
# Epoch 39, Loss: 0.0010, Train Accuracy: 1.0000, Test Accuracy: 0.7011
# Epoch 40, Loss: 0.0009, Train Accuracy: 1.0000, Test Accuracy: 0.7018
# Epoch 41, Loss: 0.0008, Train Accuracy: 1.0000, Test Accuracy: 0.7008
# Epoch 42, Loss: 0.0007, Train Accuracy: 1.0000, Test Accuracy: 0.7006
# Epoch 43, Loss: 0.0006, Train Accuracy: 1.0000, Test Accuracy: 0.7011
# Epoch 44, Loss: 0.0006, Train Accuracy: 1.0000, Test Accuracy: 0.6997
# Epoch 45, Loss: 0.0005, Train Accuracy: 1.0000, Test Accuracy: 0.7020
# Epoch 46, Loss: 0.0005, Train Accuracy: 1.0000, Test Accuracy: 0.7012
# Epoch 47, Loss: 0.0004, Train Accuracy: 1.0000, Test Accuracy: 0.7010
# Epoch 48, Loss: 0.0004, Train Accuracy: 1.0000, Test Accuracy: 0.7019
# Epoch 49, Loss: 0.0003, Train Accuracy: 1.0000, Test Accuracy: 0.7014
# Epoch 50, Loss: 0.0003, Train Accuracy: 1.0000, Test Accuracy: 0.7015
# Epoch 1, Loss: 1.8612, Train Accuracy: 0.4277, Test Accuracy: 0.4231
# Epoch 2, Loss: 1.5590, Train Accuracy: 0.4756, Test Accuracy: 0.4682
# Epoch 3, Loss: 1.4387, Train Accuracy: 0.5107, Test Accuracy: 0.4951
# Epoch 4, Loss: 1.3527, Train Accuracy: 0.5421, Test Accuracy: 0.5260
# Epoch 5, Loss: 1.2828, Train Accuracy: 0.5653, Test Accuracy: 0.5473
# Epoch 6, Loss: 1.2332, Train Accuracy: 0.5810, Test Accuracy: 0.5631
# Epoch 7, Loss: 1.1879, Train Accuracy: 0.6013, Test Accuracy: 0.5819
# Epoch 8, Loss: 1.1496, Train Accuracy: 0.6074, Test Accuracy: 0.5832
# Epoch 9, Loss: 1.1239, Train Accuracy: 0.6173, Test Accuracy: 0.5927
# Epoch 10, Loss: 1.0889, Train Accuracy: 0.6307, Test Accuracy: 0.6030
# Epoch 11, Loss: 1.0614, Train Accuracy: 0.6453, Test Accuracy: 0.6123
# Epoch 12, Loss: 1.0348, Train Accuracy: 0.6496, Test Accuracy: 0.6170
# Epoch 13, Loss: 1.0113, Train Accuracy: 0.6588, Test Accuracy: 0.6257
# Epoch 14, Loss: 0.9895, Train Accuracy: 0.6711, Test Accuracy: 0.6323
# Epoch 15, Loss: 0.9653, Train Accuracy: 0.6790, Test Accuracy: 0.6359
# Epoch 16, Loss: 0.9452, Train Accuracy: 0.6878, Test Accuracy: 0.6425
# Epoch 17, Loss: 0.9325, Train Accuracy: 0.6873, Test Accuracy: 0.6381
# Epoch 18, Loss: 0.9147, Train Accuracy: 0.6966, Test Accuracy: 0.6490
# Epoch 19, Loss: 0.8961, Train Accuracy: 0.7007, Test Accuracy: 0.6501
# Epoch 20, Loss: 0.8796, Train Accuracy: 0.7095, Test Accuracy: 0.6525
# Epoch 21, Loss: 0.8658, Train Accuracy: 0.7068, Test Accuracy: 0.6463
# Epoch 22, Loss: 0.8513, Train Accuracy: 0.7234, Test Accuracy: 0.6619
# Epoch 23, Loss: 0.8385, Train Accuracy: 0.7242, Test Accuracy: 0.6598
# Epoch 24, Loss: 0.8243, Train Accuracy: 0.7248, Test Accuracy: 0.6602
# Epoch 25, Loss: 0.8098, Train Accuracy: 0.7251, Test Accuracy: 0.6583
# Epoch 26, Loss: 0.7970, Train Accuracy: 0.7400, Test Accuracy: 0.6666
# Epoch 27, Loss: 0.7866, Train Accuracy: 0.7311, Test Accuracy: 0.6554
# Epoch 28, Loss: 0.7725, Train Accuracy: 0.7427, Test Accuracy: 0.6687
# Epoch 29, Loss: 0.7616, Train Accuracy: 0.7451, Test Accuracy: 0.6678
# Epoch 30, Loss: 0.7486, Train Accuracy: 0.7552, Test Accuracy: 0.6702
# Epoch 31, Loss: 0.7402, Train Accuracy: 0.7530, Test Accuracy: 0.6697
# Epoch 32, Loss: 0.7280, Train Accuracy: 0.7666, Test Accuracy: 0.6782
# Epoch 33, Loss: 0.7158, Train Accuracy: 0.7627, Test Accuracy: 0.6758
# Epoch 34, Loss: 0.7092, Train Accuracy: 0.7541, Test Accuracy: 0.6637
# Epoch 35, Loss: 0.6956, Train Accuracy: 0.7752, Test Accuracy: 0.6746
# Epoch 36, Loss: 0.6888, Train Accuracy: 0.7657, Test Accuracy: 0.6714
# Epoch 37, Loss: 0.6772, Train Accuracy: 0.7751, Test Accuracy: 0.6741
# Epoch 38, Loss: 0.6666, Train Accuracy: 0.7903, Test Accuracy: 0.6837
# Epoch 39, Loss: 0.6536, Train Accuracy: 0.7910, Test Accuracy: 0.6803
# Epoch 40, Loss: 0.6468, Train Accuracy: 0.7904, Test Accuracy: 0.6833
# Epoch 41, Loss: 0.6352, Train Accuracy: 0.7960, Test Accuracy: 0.6852
# Epoch 42, Loss: 0.6252, Train Accuracy: 0.7837, Test Accuracy: 0.6775
# Epoch 43, Loss: 0.6153, Train Accuracy: 0.8034, Test Accuracy: 0.6822
# Epoch 44, Loss: 0.6042, Train Accuracy: 0.8063, Test Accuracy: 0.6847
# Epoch 45, Loss: 0.5916, Train Accuracy: 0.8095, Test Accuracy: 0.6827
# Epoch 46, Loss: 0.5868, Train Accuracy: 0.8149, Test Accuracy: 0.6860
# Epoch 47, Loss: 0.5760, Train Accuracy: 0.8191, Test Accuracy: 0.6900
# Epoch 48, Loss: 0.5684, Train Accuracy: 0.8259, Test Accuracy: 0.6861
# Epoch 49, Loss: 0.5572, Train Accuracy: 0.8168, Test Accuracy: 0.6820
# Epoch 50, Loss: 0.5484, Train Accuracy: 0.8280, Test Accuracy: 0.6873

# %% [markdown]
# ## Step 4: Leaky ReLU와 Sigmoid 성능 비교

# %%
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torch

# 모델 가중치 초기화 함수
def initialize_weights(model):
    for layer in model.modules():
        if isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear):
            nn.init.kaiming_normal_(layer.weight)  # He 초기화
            if layer.bias is not None:
                nn.init.zeros_(layer.bias)  # bias 초기화

# LeakyReLU 모델 정의
class LeakyReLUNet(nn.Module):
    def __init__(self):
        super(LeakyReLUNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(64 * 8 * 8, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(nn.LeakyReLU()(self.conv1(x)))
        x = self.pool(nn.LeakyReLU()(self.conv2(x)))
        x = x.view(-1, 64 * 8 * 8)
        x = nn.LeakyReLU()(self.fc1(x))
        x = self.fc2(x)
        return x

# Sigmoid 모델 정의
class SigmoidNet(nn.Module):
    def __init__(self):
        super(SigmoidNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(64 * 8 * 8, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(nn.Sigmoid()(self.conv1(x)))
        x = self.pool(nn.Sigmoid()(self.conv2(x)))
        x = x.view(-1, 64 * 8 * 8)
        x = nn.Sigmoid()(self.fc1(x))
        x = self.fc2(x)
        return x

def accuracy(model, dataloader):
    cnt = 0
    acc = 0
    model.eval()  # 평가 모드로 설정
    with torch.no_grad():  # Gradient 계산 안 함
        for data in dataloader:
            inputs, labels = data
            inputs, labels = inputs.to('cuda'), labels.to('cuda')

            preds = model(inputs)
            preds = torch.argmax(preds, dim=-1)  # 예측값의 인덱스 (클래스)
            cnt += labels.shape[0]
            acc += (labels == preds).sum().item()

    return acc / cnt

def train_model(optimizer_name="adam", model=None):
    # Optimizer 설정
    if optimizer_name == "adam":
        optimizer = optim.Adam(model.parameters(), lr=0.001)
    elif optimizer_name == "sgd":
        optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

    n_epochs = 50
    train_accuracies = []
    test_accuracies = []

    for epoch in range(n_epochs):
        model.train()  # 학습 모드로 설정
        running_loss = 0.0

        for data in trainloader:
            inputs, labels = data
            inputs, labels = inputs.to('cuda'), labels.to('cuda')

            # 옵티마이저 초기화
            optimizer.zero_grad()

            # Forward
            outputs = model(inputs)
            loss = loss_fn(outputs, labels)

            # Backward
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        # 매 에포크마다 train과 test 정확도 계산
        train_acc = accuracy(model, trainloader)
        test_acc = accuracy(model, testloader)

        train_accuracies.append(train_acc)
        test_accuracies.append(test_acc)

        print(f'Epoch {epoch+1}, Loss: {running_loss/len(trainloader):.4f}, '
              f'Train Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}')

    return train_accuracies, test_accuracies

# Leaky ReLU 모델 학습
model_leaky_relu = LeakyReLUNet().to('cuda')
loss_fn = nn.CrossEntropyLoss()
initialize_weights(model_leaky_relu)
leaky_relu_train_acc, _ = train_model("adam", model=model_leaky_relu)

# Sigmoid 모델 학습
model_sigmoid = SigmoidNet().to('cuda')
initialize_weights(model_sigmoid)
sigmoid_train_acc, _ = train_model("adam", model=model_sigmoid)

# Plot 2: Sigmoid와 Leaky ReLU 성능 비교
import matplotlib.pyplot as plt
def plot_acc(train_acc1, train_acc2, label1='LeakyReLU', label2='Sigmoid'):
    x = np.arange(len(train_acc1))

    plt.plot(x, train_acc1, label=label1)
    plt.plot(x, train_acc2, label=label2)
    plt.xlabel('Epochs')
    plt.ylabel('Train Accuracy')
    plt.legend()
    plt.show()

plot_acc(leaky_relu_train_acc, sigmoid_train_acc)
# Out:
# Epoch 1, Loss: 1.5551, Train Accuracy: 0.5887, Test Accuracy: 0.5711
# Epoch 2, Loss: 1.0904, Train Accuracy: 0.6657, Test Accuracy: 0.6310
# Epoch 3, Loss: 0.9282, Train Accuracy: 0.7029, Test Accuracy: 0.6577
# Epoch 4, Loss: 0.8319, Train Accuracy: 0.7486, Test Accuracy: 0.6880
# Epoch 5, Loss: 0.7483, Train Accuracy: 0.7694, Test Accuracy: 0.6933
# Epoch 6, Loss: 0.6809, Train Accuracy: 0.7936, Test Accuracy: 0.6915
# Epoch 7, Loss: 0.6294, Train Accuracy: 0.8068, Test Accuracy: 0.6989
# Epoch 8, Loss: 0.5682, Train Accuracy: 0.8365, Test Accuracy: 0.7092
# Epoch 9, Loss: 0.5141, Train Accuracy: 0.8449, Test Accuracy: 0.7074
# Epoch 10, Loss: 0.4638, Train Accuracy: 0.8669, Test Accuracy: 0.7085
# Epoch 11, Loss: 0.4079, Train Accuracy: 0.8913, Test Accuracy: 0.7164
# Epoch 12, Loss: 0.3695, Train Accuracy: 0.9037, Test Accuracy: 0.7090
# Epoch 13, Loss: 0.3220, Train Accuracy: 0.9195, Test Accuracy: 0.7113
# Epoch 14, Loss: 0.2761, Train Accuracy: 0.9280, Test Accuracy: 0.7046
# Epoch 15, Loss: 0.2340, Train Accuracy: 0.9515, Test Accuracy: 0.7111
# Epoch 16, Loss: 0.2027, Train Accuracy: 0.9517, Test Accuracy: 0.7001
# Epoch 17, Loss: 0.1620, Train Accuracy: 0.9670, Test Accuracy: 0.7071
# Epoch 18, Loss: 0.1319, Train Accuracy: 0.9734, Test Accuracy: 0.7044
# Epoch 19, Loss: 0.1050, Train Accuracy: 0.9878, Test Accuracy: 0.7093
# Epoch 20, Loss: 0.0883, Train Accuracy: 0.9787, Test Accuracy: 0.6985
# Epoch 21, Loss: 0.0747, Train Accuracy: 0.9897, Test Accuracy: 0.7091
# Epoch 22, Loss: 0.0588, Train Accuracy: 0.9933, Test Accuracy: 0.7011
# Epoch 23, Loss: 0.0521, Train Accuracy: 0.9938, Test Accuracy: 0.7017
# Epoch 24, Loss: 0.0369, Train Accuracy: 0.9932, Test Accuracy: 0.7028
# Epoch 25, Loss: 0.0443, Train Accuracy: 0.9862, Test Accuracy: 0.6977
# Epoch 26, Loss: 0.0497, Train Accuracy: 0.9886, Test Accuracy: 0.6972
# Epoch 27, Loss: 0.0763, Train Accuracy: 0.9750, Test Accuracy: 0.6978
# Epoch 28, Loss: 0.0655, Train Accuracy: 0.9910, Test Accuracy: 0.6963
# Epoch 29, Loss: 0.0288, Train Accuracy: 0.9965, Test Accuracy: 0.7004
# Epoch 30, Loss: 0.0140, Train Accuracy: 0.9988, Test Accuracy: 0.7038
# Epoch 31, Loss: 0.0070, Train Accuracy: 1.0000, Test Accuracy: 0.7057
# Epoch 32, Loss: 0.0030, Train Accuracy: 1.0000, Test Accuracy: 0.7069
# Epoch 33, Loss: 0.0020, Train Accuracy: 1.0000, Test Accuracy: 0.7061
# Epoch 34, Loss: 0.0016, Train Accuracy: 1.0000, Test Accuracy: 0.7072
# Epoch 35, Loss: 0.0014, Train Accuracy: 1.0000, Test Accuracy: 0.7085
# Epoch 36, Loss: 0.0012, Train Accuracy: 1.0000, Test Accuracy: 0.7077
# Epoch 37, Loss: 0.0010, Train Accuracy: 1.0000, Test Accuracy: 0.7076
# Epoch 38, Loss: 0.0009, Train Accuracy: 1.0000, Test Accuracy: 0.7082
# Epoch 39, Loss: 0.0008, Train Accuracy: 1.0000, Test Accuracy: 0.7075
# Epoch 40, Loss: 0.0007, Train Accuracy: 1.0000, Test Accuracy: 0.7079
# Epoch 41, Loss: 0.0006, Train Accuracy: 1.0000, Test Accuracy: 0.7071
# Epoch 42, Loss: 0.0006, Train Accuracy: 1.0000, Test Accuracy: 0.7080
# Epoch 43, Loss: 0.0005, Train Accuracy: 1.0000, Test Accuracy: 0.7088
# Epoch 44, Loss: 0.3440, Train Accuracy: 0.9410, Test Accuracy: 0.6897
# Epoch 45, Loss: 0.1328, Train Accuracy: 0.9843, Test Accuracy: 0.6973
# Epoch 46, Loss: 0.0457, Train Accuracy: 0.9885, Test Accuracy: 0.6986
# Epoch 47, Loss: 0.0191, Train Accuracy: 0.9989, Test Accuracy: 0.7051
# Epoch 48, Loss: 0.0056, Train Accuracy: 1.0000, Test Accuracy: 0.7127
# Epoch 49, Loss: 0.0023, Train Accuracy: 1.0000, Test Accuracy: 0.7134
# Epoch 50, Loss: 0.0016, Train Accuracy: 1.0000, Test Accuracy: 0.7131
# Epoch 1, Loss: 2.0963, Train Accuracy: 0.3416, Test Accuracy: 0.3494
# Epoch 2, Loss: 1.7352, Train Accuracy: 0.4178, Test Accuracy: 0.4242
# Epoch 3, Loss: 1.5824, Train Accuracy: 0.4720, Test Accuracy: 0.4735
# Epoch 4, Loss: 1.4737, Train Accuracy: 0.5012, Test Accuracy: 0.4956
# Epoch 5, Loss: 1.3789, Train Accuracy: 0.5195, Test Accuracy: 0.5133
# Epoch 6, Loss: 1.3077, Train Accuracy: 0.5570, Test Accuracy: 0.5460
# Epoch 7, Loss: 1.2478, Train Accuracy: 0.5647, Test Accuracy: 0.5490
# Epoch 8, Loss: 1.1970, Train Accuracy: 0.5907, Test Accuracy: 0.5698
# Epoch 9, Loss: 1.1547, Train Accuracy: 0.6096, Test Accuracy: 0.5846
# Epoch 10, Loss: 1.1163, Train Accuracy: 0.6269, Test Accuracy: 0.6010
# Epoch 11, Loss: 1.0766, Train Accuracy: 0.6350, Test Accuracy: 0.6049
# Epoch 12, Loss: 1.0380, Train Accuracy: 0.6500, Test Accuracy: 0.6154
# Epoch 13, Loss: 1.0053, Train Accuracy: 0.6644, Test Accuracy: 0.6231
# Epoch 14, Loss: 0.9694, Train Accuracy: 0.6854, Test Accuracy: 0.6374
# Epoch 15, Loss: 0.9449, Train Accuracy: 0.6885, Test Accuracy: 0.6348
# Epoch 16, Loss: 0.9090, Train Accuracy: 0.6871, Test Accuracy: 0.6318
# Epoch 17, Loss: 0.8848, Train Accuracy: 0.7085, Test Accuracy: 0.6481
# Epoch 18, Loss: 0.8531, Train Accuracy: 0.7188, Test Accuracy: 0.6562
# Epoch 19, Loss: 0.8328, Train Accuracy: 0.7135, Test Accuracy: 0.6460
# Epoch 20, Loss: 0.8060, Train Accuracy: 0.7306, Test Accuracy: 0.6554
# Epoch 21, Loss: 0.7812, Train Accuracy: 0.7179, Test Accuracy: 0.6449
# Epoch 22, Loss: 0.7628, Train Accuracy: 0.7569, Test Accuracy: 0.6664
# Epoch 23, Loss: 0.7329, Train Accuracy: 0.7643, Test Accuracy: 0.6697
# Epoch 24, Loss: 0.7109, Train Accuracy: 0.7617, Test Accuracy: 0.6636
# Epoch 25, Loss: 0.6910, Train Accuracy: 0.7758, Test Accuracy: 0.6703
# Epoch 26, Loss: 0.6656, Train Accuracy: 0.7808, Test Accuracy: 0.6677
# Epoch 27, Loss: 0.6487, Train Accuracy: 0.7951, Test Accuracy: 0.6721
# Epoch 28, Loss: 0.6205, Train Accuracy: 0.8079, Test Accuracy: 0.6774
# Epoch 29, Loss: 0.6060, Train Accuracy: 0.8090, Test Accuracy: 0.6738
# Epoch 30, Loss: 0.5835, Train Accuracy: 0.8223, Test Accuracy: 0.6809
# Epoch 31, Loss: 0.5617, Train Accuracy: 0.8302, Test Accuracy: 0.6777
# Epoch 32, Loss: 0.5412, Train Accuracy: 0.8359, Test Accuracy: 0.6820
# Epoch 33, Loss: 0.5247, Train Accuracy: 0.8455, Test Accuracy: 0.6786
# Epoch 34, Loss: 0.5067, Train Accuracy: 0.8495, Test Accuracy: 0.6811
# Epoch 35, Loss: 0.4813, Train Accuracy: 0.8563, Test Accuracy: 0.6780
# Epoch 36, Loss: 0.4662, Train Accuracy: 0.8605, Test Accuracy: 0.6806
# Epoch 37, Loss: 0.4435, Train Accuracy: 0.8699, Test Accuracy: 0.6809
# Epoch 38, Loss: 0.4250, Train Accuracy: 0.8771, Test Accuracy: 0.6801
# Epoch 39, Loss: 0.4050, Train Accuracy: 0.8842, Test Accuracy: 0.6833
# Epoch 40, Loss: 0.3848, Train Accuracy: 0.8892, Test Accuracy: 0.6800
# Epoch 41, Loss: 0.3714, Train Accuracy: 0.9050, Test Accuracy: 0.6780
# Epoch 42, Loss: 0.3540, Train Accuracy: 0.9126, Test Accuracy: 0.6782
# Epoch 43, Loss: 0.3330, Train Accuracy: 0.9208, Test Accuracy: 0.6827
# Epoch 44, Loss: 0.3145, Train Accuracy: 0.9222, Test Accuracy: 0.6792
# Epoch 45, Loss: 0.2990, Train Accuracy: 0.9316, Test Accuracy: 0.6791
# Epoch 46, Loss: 0.2811, Train Accuracy: 0.9335, Test Accuracy: 0.6758
# Epoch 47, Loss: 0.2670, Train Accuracy: 0.9473, Test Accuracy: 0.6807
# Epoch 48, Loss: 0.2520, Train Accuracy: 0.9507, Test Accuracy: 0.6789
# Epoch 49, Loss: 0.2352, Train Accuracy: 0.9571, Test Accuracy: 0.6803
# Epoch 50, Loss: 0.2195, Train Accuracy: 0.9634, Test Accuracy: 0.6783

# %% [markdown]
# ## Step 5: Dropout 적용 후 generalization error 확인

# %%
class DropoutNet(nn.Module):
    def __init__(self):
        super(DropoutNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(64 * 8 * 8, 128)
        self.fc2 = nn.Linear(128, 10)
        self.dropout = nn.Dropout(0.1)  # Dropout 적용

    def forward(self, x):
        x = self.pool(nn.LeakyReLU()(self.conv1(x)))
        x = self.pool(nn.LeakyReLU()(self.conv2(x)))
        x = x.view(-1, 64 * 8 * 8)
        x = self.dropout(nn.LeakyReLU()(self.fc1(x)))  # Dropout 적용
        x = self.fc2(x)
        return x

# Dropout 모델 학습
model_dropout = DropoutNet().to('cuda')
initialize_weights(model_dropout)  # 가중치 초기화
dropout_train_acc, dropout_test_acc = train_model("adam", model=model_dropout)

# Plot 3: Dropout 적용 후 성능 비교
plot_acc(dropout_train_acc, dropout_test_acc, label1="Train", label2="Test")
# Out:
# Epoch 1, Loss: 1.6081, Train Accuracy: 0.5791, Test Accuracy: 0.5608
# Epoch 2, Loss: 1.1468, Train Accuracy: 0.6722, Test Accuracy: 0.6344
# Epoch 3, Loss: 0.9673, Train Accuracy: 0.7103, Test Accuracy: 0.6574
# Epoch 4, Loss: 0.8529, Train Accuracy: 0.7431, Test Accuracy: 0.6712
# Epoch 5, Loss: 0.7649, Train Accuracy: 0.7846, Test Accuracy: 0.6914
# Epoch 6, Loss: 0.6815, Train Accuracy: 0.8119, Test Accuracy: 0.6960
# Epoch 7, Loss: 0.6226, Train Accuracy: 0.8410, Test Accuracy: 0.7023
# Epoch 8, Loss: 0.5509, Train Accuracy: 0.8694, Test Accuracy: 0.7122
# Epoch 9, Loss: 0.4928, Train Accuracy: 0.8828, Test Accuracy: 0.7077
# Epoch 10, Loss: 0.4385, Train Accuracy: 0.9138, Test Accuracy: 0.7151
# Epoch 11, Loss: 0.3851, Train Accuracy: 0.9256, Test Accuracy: 0.7110
# Epoch 12, Loss: 0.3350, Train Accuracy: 0.9379, Test Accuracy: 0.7091
# Epoch 13, Loss: 0.2912, Train Accuracy: 0.9510, Test Accuracy: 0.7055
# Epoch 14, Loss: 0.2624, Train Accuracy: 0.9671, Test Accuracy: 0.7074
# Epoch 15, Loss: 0.2229, Train Accuracy: 0.9745, Test Accuracy: 0.7101
# Epoch 16, Loss: 0.1993, Train Accuracy: 0.9778, Test Accuracy: 0.7068
# Epoch 17, Loss: 0.1742, Train Accuracy: 0.9798, Test Accuracy: 0.7020
# Epoch 18, Loss: 0.1543, Train Accuracy: 0.9856, Test Accuracy: 0.7026
# Epoch 19, Loss: 0.1443, Train Accuracy: 0.9861, Test Accuracy: 0.6982
# Epoch 20, Loss: 0.1295, Train Accuracy: 0.9854, Test Accuracy: 0.6982
# Epoch 21, Loss: 0.1182, Train Accuracy: 0.9927, Test Accuracy: 0.7075
# Epoch 22, Loss: 0.1078, Train Accuracy: 0.9918, Test Accuracy: 0.7022
# Epoch 23, Loss: 0.1053, Train Accuracy: 0.9921, Test Accuracy: 0.7049
# Epoch 24, Loss: 0.0959, Train Accuracy: 0.9930, Test Accuracy: 0.7023
# Epoch 25, Loss: 0.0915, Train Accuracy: 0.9922, Test Accuracy: 0.7019
# Epoch 26, Loss: 0.0852, Train Accuracy: 0.9942, Test Accuracy: 0.7002
# Epoch 27, Loss: 0.0888, Train Accuracy: 0.9844, Test Accuracy: 0.6971
# Epoch 28, Loss: 0.0877, Train Accuracy: 0.9929, Test Accuracy: 0.7026
# Epoch 29, Loss: 0.0789, Train Accuracy: 0.9958, Test Accuracy: 0.7023
# Epoch 30, Loss: 0.0781, Train Accuracy: 0.9969, Test Accuracy: 0.7034
# Epoch 31, Loss: 0.0686, Train Accuracy: 0.9961, Test Accuracy: 0.7058
# Epoch 32, Loss: 0.0671, Train Accuracy: 0.9974, Test Accuracy: 0.7035
# Epoch 33, Loss: 0.0689, Train Accuracy: 0.9923, Test Accuracy: 0.6938
# Epoch 34, Loss: 0.0689, Train Accuracy: 0.9952, Test Accuracy: 0.6969
# Epoch 35, Loss: 0.0696, Train Accuracy: 0.9936, Test Accuracy: 0.6980
# Epoch 36, Loss: 0.0649, Train Accuracy: 0.9963, Test Accuracy: 0.6988
# Epoch 37, Loss: 0.0543, Train Accuracy: 0.9979, Test Accuracy: 0.7015
# Epoch 38, Loss: 0.0568, Train Accuracy: 0.9963, Test Accuracy: 0.6974
# Epoch 39, Loss: 0.0600, Train Accuracy: 0.9974, Test Accuracy: 0.7012
# Epoch 40, Loss: 0.0588, Train Accuracy: 0.9971, Test Accuracy: 0.6978
# Epoch 41, Loss: 0.0586, Train Accuracy: 0.9964, Test Accuracy: 0.7021
# Epoch 42, Loss: 0.0501, Train Accuracy: 0.9968, Test Accuracy: 0.6953
# Epoch 43, Loss: 0.0528, Train Accuracy: 0.9982, Test Accuracy: 0.6954
# Epoch 44, Loss: 0.0532, Train Accuracy: 0.9956, Test Accuracy: 0.6960
# Epoch 45, Loss: 0.0575, Train Accuracy: 0.9966, Test Accuracy: 0.6954
# Epoch 46, Loss: 0.0501, Train Accuracy: 0.9981, Test Accuracy: 0.6994
# Epoch 47, Loss: 0.0532, Train Accuracy: 0.9988, Test Accuracy: 0.7029
# Epoch 48, Loss: 0.0480, Train Accuracy: 0.9974, Test Accuracy: 0.6955
# Epoch 49, Loss: 0.0510, Train Accuracy: 0.9985, Test Accuracy: 0.7000
# Epoch 50, Loss: 0.0464, Train Accuracy: 0.9973, Test Accuracy: 0.6957

# %% [markdown]
# ## Step 6: 모델 예측과 실제 데이터 정답 체크

# %%
# Step 6: 모델 예측과 실제 정답 비교
model_dropout.eval()  # 평가 모드
correct = 0
total = 0

with torch.no_grad():  # 학습 모드가 아니므로 no_grad() 사용
    for idx in range(10):  # 처음 10개 데이터에 대해 예측
        image, label = testset[idx][0], testset[idx][1]  # 이미지와 실제 정답 가져오기
        image = image.unsqueeze(0).to('cuda')  # 배치 차원 추가 및 GPU로 이동

        output = model_dropout(image)  # 모델 예측
        pred = torch.argmax(output, dim=1).item()  # 예측값 추출

        # 예측값과 실제 레이블 비교
        correct_prediction = (pred == label)
        result = "맞았습니다!" if correct_prediction else "틀렸습니다."

        # 결과 출력
        print(f'이미지 {idx + 1}: 모델 예측 = {pred}, 실제 정답 = {label} ({result})')

        # 정확도 계산용
        if correct_prediction:
            correct += 1
        total += 1

print(f"\n처음 10개 이미지에서 모델의 정확도: {correct}/{total}")
# Out:
# 이미지 1: 모델 예측 = 3, 실제 정답 = 3 (맞았습니다!)
# 이미지 2: 모델 예측 = 8, 실제 정답 = 8 (맞았습니다!)
# 이미지 3: 모델 예측 = 8, 실제 정답 = 8 (맞았습니다!)
# 이미지 4: 모델 예측 = 0, 실제 정답 = 0 (맞았습니다!)
# 이미지 5: 모델 예측 = 6, 실제 정답 = 6 (맞았습니다!)
# 이미지 6: 모델 예측 = 6, 실제 정답 = 6 (맞았습니다!)
# 이미지 7: 모델 예측 = 1, 실제 정답 = 1 (맞았습니다!)
# 이미지 8: 모델 예측 = 2, 실제 정답 = 6 (틀렸습니다.)
# 이미지 9: 모델 예측 = 3, 실제 정답 = 3 (맞았습니다!)
# 이미지 10: 모델 예측 = 1, 실제 정답 = 1 (맞았습니다!)
#
# 처음 10개 이미지에서 모델의 정확도: 9/10
